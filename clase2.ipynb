# %% [markdown]
# # Estructura de datos

# %%
nombre = "Pepe"

if nombre == "Jose":
    print("Es Jose")
elif nombre == "Luis":
    print("Es Luis")
else:
    print("Es Otro")
# Out:
# Es Otro

# %% [markdown]
# # Operadores Relacionales

# %%
esMayor = 5>6
esMayor
# Out:
# False

# %%
if (esMayor):
    print("Es Cierto")
else:
    print("Es Mentira")
# Out:
# Es Mentira

# %%
edad = int(input("Ingrese su edad:"))

if edad >= 18:
    print("Es mayor de edad")
    
elif edad >= 30 <= 40:
    print("Es Añoso")
else:
    print("Es menor de edad")
# Out:
# Ingrese su edad: 23
# Es mayor de edad
